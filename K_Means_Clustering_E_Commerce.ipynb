# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiwari666/K_Means_Clustering/blob/main/K_Means_Clustering_E_Commerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
df = pd.read_excel('/content/Online_Retail_Customer_Segmentation.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # **EDA:**

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.value_counts('CustomerID')
# Out:
# CustomerID
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 14119.0       1
# 13747.0       1
# 15590.0       1
# 15562.0       1
# 17925.0       1
# Length: 4372, dtype: int64

# %%
df.isna().sum()* 100 / len(df)
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.value_counts()
# Out:
# InvoiceNo  StockCode  Description                          Quantity  InvoiceDate          UnitPrice  CustomerID  Country
# 555524     22698      PINK REGENCY TEACUP AND SAUCER        1        2011-06-05 11:37:00  2.95       16923.0     United Kingdom    20
#            22697      GREEN REGENCY TEACUP AND SAUCER       1        2011-06-05 11:37:00  2.95       16923.0     United Kingdom    12
# 572861     22775      PURPLE DRAWERKNOB ACRYLIC EDWARDIAN   12       2011-10-26 12:46:00  1.25       14102.0     United Kingdom     8
# 572344     M          Manual                                48       2011-10-24 10:43:00  1.50       14607.0     United Kingdom     6
# 578289     23395      BELLE JARDINIERE CUSHION COVER        1        2011-11-23 14:07:00  3.75       17841.0     United Kingdom     6
#                                                                                                                                    ..
# 553915     21174      POTTERING IN THE SHED METAL SIGN      12       2011-05-19 19:51:00  2.08       18225.0     United Kingdom     1
#            21165      BEWARE OF THE CAT METAL SIGN          12       2011-05-19 19:51:00  1.69       18225.0     United Kingdom     1
#            21080      SET/20 RED RETROSPOT PAPER NAPKINS    12       2011-05-19 19:51:00  0.85       18225.0     United Kingdom     1
#            21078      SET/20 STRAWBERRY PAPER NAPKINS       12       2011-05-19 19:51:00  0.85       18225.0     United Kingdom     1
# C581569    84978      HANGING HEART JAR T-LIGHT HOLDER     -1        2011-12-09 11:58:00  1.25       17315.0     United Kingdom     1
# Length: 401604, dtype: int64

# %% [markdown]
# # **Data Preprocessing:**
#
# # **Handling Missing Values**
#
# It is found that approximately a quarter of Customer ID is missing, and 0.2% of description of product are missing.  we will remove all of the rows with missing values of the CustomerID as the CustomerID is significant variable for the analysis.

# %%
#removing missing values
df.dropna(inplace=True)

# %%
#resetting the index
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (406829, 8)

# %%
print('Number of missing values in the dataset: ', df.isnull().values.sum())
print('Data lenght: ', len(df))
# Out:
# Number of missing values in the dataset:  0
# Data lenght:  406829

# %% [markdown]
# # **Checking for duplicate rows to find a different product purchased by the same customer**:

# %%
duplicates_df = df.duplicated()
print("Number of duplicate values: ", duplicates_df.sum())
# Out:
# Number of duplicate values:  5225

# %%
#selecting the first duplicated row
duplicated_row = df[duplicates_df == True].iloc[0]
df[duplicates_df == True].head()
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 517    536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527    536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537    536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539    536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555    536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 517 2010-12-01 11:45:00       1.25     17908.0  United Kingdom
# 527 2010-12-01 11:45:00       2.10     17908.0  United Kingdom
# 537 2010-12-01 11:45:00       2.95     17908.0  United Kingdom
# 539 2010-12-01 11:45:00       4.95     17908.0  United Kingdom
# 555 2010-12-01 11:49:00       2.95     17920.0  United Kingdom

# %% [markdown]
# # **Handling the unusual data:**

# %%
df['Quantity'].value_counts()
# Out:
#  1        73314
#  12       60033
#  2        58003
#  6        37688
#  4        32183
#           ...
#  828          1
#  560          1
# -408          1
#  512          1
# -80995        1
# Name: Quantity, Length: 436, dtype: int64

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df[df['Quantity']<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 406377   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 406461   C581499         M                            Manual        -1
# 406635   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 406636   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 406637   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 406377 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 406461 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 406635 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 406636 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 406637 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [8905 rows x 8 columns]

# %% [markdown]
# We see that there are 8905 "Quantity" in negative number. Since the quantity cannot be negative, we will drop these negative "Quantity" rows.

# %%
#checking the unit price feature
df[df['UnitPrice'] > 1000]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 28939    C540271         M           Manual        -1 2011-01-06 11:51:00
# 45380    C542348         M           Manual        -1 2011-01-27 12:09:00
# 78283    C546325         M           Manual        -1 2011-03-11 10:15:00
# 78284    C546327         M           Manual        -1 2011-03-11 10:18:00
# 78285     546328         M           Manual         1 2011-03-11 10:19:00
# 78286     546329         M           Manual         1 2011-03-11 10:22:00
# 99563     548813         M           Manual         1 2011-04-04 13:03:00
# 99565     548813         M           Manual         1 2011-04-04 13:03:00
# 99566     548820         M           Manual         1 2011-04-04 13:04:00
# 99568    C548830         M           Manual        -1 2011-04-04 13:08:00
# 99570    C548830         M           Manual        -1 2011-04-04 13:08:00
# 99571    C548834         M           Manual        -1 2011-04-04 13:09:00
# 100107    548913         M           Manual         1 2011-04-05 09:45:00
# 100108   C548914         M           Manual        -1 2011-04-05 09:46:00
# 104088   C549452         D         Discount        -1 2011-04-08 14:17:00
# 104098    549468         M           Manual         1 2011-04-08 14:27:00
# 121297   C551685      POST          POSTAGE        -1 2011-05-03 12:51:00
# 121396    551697      POST          POSTAGE         1 2011-05-03 13:46:00
# 121405   C551699         M           Manual        -1 2011-05-03 14:12:00
# 142723   C554154         M           Manual        -1 2011-05-23 11:24:00
# 142724    554155         M           Manual         1 2011-05-23 11:26:00
# 143411    554301         M           Manual         1 2011-05-23 14:46:00
# 143412   C554302         M           Manual        -1 2011-05-23 14:50:00
# 159240   C556445         M           Manual        -1 2011-06-10 15:31:00
# 191463   C560372         M           Manual        -1 2011-07-18 12:26:00
# 191852   C560420         M           Manual        -1 2011-07-18 15:11:00
# 193788   C560647         M           Manual        -1 2011-07-20 11:31:00
# 211473   C562647         M           Manual        -1 2011-08-08 12:56:00
# 213801   C562938         M           Manual        -1 2011-08-10 17:14:00
# 213869    562946         M           Manual         1 2011-08-11 09:38:00
# 249995   C566925         M           Manual        -1 2011-09-15 15:18:00
# 249999    566927         M           Manual         1 2011-09-15 15:20:00
# 275959    569382         M           Manual         1 2011-10-03 16:44:00
# 302431   C571750         M           Manual        -1 2011-10-19 11:16:00
# 302432   C571750         M           Manual        -1 2011-10-19 11:16:00
# 302433    571751         M           Manual         1 2011-10-19 11:18:00
# 302434    571751         M           Manual         1 2011-10-19 11:18:00
# 316257    573077         M           Manual         1 2011-10-27 14:13:00
# 316281   C573079         M           Manual        -2 2011-10-27 14:15:00
# 316282    573080         M           Manual         1 2011-10-27 14:20:00
# 352564    576339       DOT   DOTCOM POSTAGE         1 2011-11-14 15:27:00
# 352565   C576338      CRUK  CRUK Commission        -1 2011-11-14 15:27:00
# 373657    578270       DOT   DOTCOM POSTAGE         1 2011-11-23 13:39:00
# 384079    579196       DOT   DOTCOM POSTAGE         1 2011-11-28 15:54:00
# 398691    580727       DOT   DOTCOM POSTAGE         1 2011-12-05 17:17:00
# 398696   C580726      CRUK  CRUK Commission        -1 2011-12-05 17:17:00
#
#         UnitPrice  CustomerID         Country
# 28939     1126.00     12503.0           Spain
# 45380     1715.85     12539.0           Spain
# 78283     1687.17     14911.0            EIRE
# 78284     1687.17     14911.0            EIRE
# 78285     1687.17     14911.0            EIRE
# 78286     1687.17     14911.0            EIRE
# 99563     2382.92     12744.0       Singapore
# 99565     1252.95     12744.0       Singapore
# 99566     2053.07     12744.0       Singapore
# 99568     2382.92     12744.0       Singapore
# 99570     1252.95     12744.0       Singapore
# 99571     2053.07     12744.0       Singapore
# 100107    1136.30     12669.0          France
# 100108    1136.30     12669.0          France
# 104088    1867.86     17940.0  United Kingdom
# 104098    1867.86     17940.0  United Kingdom
# 121297    8142.75     16029.0  United Kingdom
# 121396    8142.75     16029.0  United Kingdom
# 121405    6930.00     16029.0  United Kingdom
# 142723    1241.98     12757.0        Portugal
# 142724    1241.98     12757.0        Portugal
# 143411    1241.98     12757.0        Portugal
# 143412    1241.98     12757.0        Portugal
# 159240   38970.00     15098.0  United Kingdom
# 191463    4287.63     17448.0  United Kingdom
# 191852    1592.49     15369.0  United Kingdom
# 193788    3060.60     18102.0  United Kingdom
# 211473    3155.95     15502.0  United Kingdom
# 213801    1121.18     14156.0            EIRE
# 213869    2500.00     15581.0  United Kingdom
# 249995    1829.84     12748.0  United Kingdom
# 249999    2033.10     17846.0  United Kingdom
# 275959    3155.95     15502.0  United Kingdom
# 302431    3949.32     12744.0       Singapore
# 302432    2118.74     12744.0       Singapore
# 302433    3949.32     12744.0       Singapore
# 302434    2118.74     12744.0       Singapore
# 316257    4161.06     12536.0          France
# 316281    4161.06     12536.0          France
# 316282    4161.06     12536.0          France
# 352564    1500.36     14096.0  United Kingdom
# 352565    1038.75     14096.0  United Kingdom
# 373657    1270.06     14096.0  United Kingdom
# 384079    1526.76     14096.0  United Kingdom
# 398691    1599.26     14096.0  United Kingdom
# 398696    1100.44     14096.0  United Kingdom

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 406377   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 406461   C581499         M                            Manual        -1
# 406635   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 406636   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 406637   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 406377 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 406461 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 406635 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 406636 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 406637 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [8905 rows x 8 columns]

# %%
df[df['Quantity'] > 1000]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 3645      536809     84950     ASSORTED COLOUR T-LIGHT HOLDER      1824
# 3740      536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 3741      536830     21915             RED  HARMONICA IN BOX       1400
# 4286      536890    17084R              ASSORTED INCENSE PACK      1440
# 10946     537659     22189            CREAM HEART CARD HOLDER      1008
# ...          ...       ...                                ...       ...
# 402106    581115     22413    METAL SIGN TAKE IT OR LEAVE IT       1404
# 403246    581175     23084                 RABBIT NIGHT LIGHT      1440
# 405998    581458     22197                     POPCORN HOLDER      1500
# 405999    581459     22197                     POPCORN HOLDER      1200
# 406349    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 3645   2010-12-02 16:48:00       0.55     15299.0  United Kingdom
# 3740   2010-12-02 17:38:00       0.18     16754.0  United Kingdom
# 3741   2010-12-02 17:38:00       1.06     16754.0  United Kingdom
# 4286   2010-12-03 11:48:00       0.16     14156.0            EIRE
# 10946  2010-12-07 16:43:00       2.31     18102.0  United Kingdom
# ...                    ...        ...         ...             ...
# 402106 2011-12-07 12:20:00       2.75     15195.0  United Kingdom
# 403246 2011-12-07 15:16:00       1.79     14646.0     Netherlands
# 405998 2011-12-08 18:45:00       0.72     17949.0  United Kingdom
# 405999 2011-12-08 18:46:00       0.72     17949.0  United Kingdom
# 406349 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
#
# [106 rows x 8 columns]

# %%
import pandas as pd
import re

# Define a regular expression pattern to match strings
pattern = re.compile('[A-Za-z]+')

# Apply the pattern to the 'StockCode' column and extract only the matches
unique_strings = df['StockCode'].apply(lambda x: ''.join(pattern.findall(str(x))))

# Compute the frequency of each unique string and reset the index
unique_SC = unique_strings.value_counts().reset_index()

# Rename the columns
unique_SC.columns = ['Categories', 'Count']

# Merge with the 'Description' column
unique_SC = unique_SC.merge(df[['StockCode', 'Description']], left_on='Categories', right_on='StockCode', how='left').drop_duplicates()

# Drop the redundant 'StockCode' column
unique_SC.drop(columns='StockCode', inplace=True)

# Display the resulting DataFrame
unique_SC
# Out:
#        Categories   Count                 Description
# 0                  371020                         NaN
# 1               B    9118                         NaN
# 2               A    8498                         NaN
# 3               C    4305                         NaN
# 4               D    2419                    Discount
# 81              L    1718                         NaN
# 82              E    1564                         NaN
# 83              F    1365                         NaN
# 84              S    1273                         NaN
# 85           POST    1196                     POSTAGE
# 1281            G    1077                         NaN
# 1282            M     767                      Manual
# 1747            P     635                         NaN
# 1748            N     444                         NaN
# 1749            K     324                         NaN
# 1750           BL     296                         NaN
# 1751            H     212                         NaN
# 1752            U     165                         NaN
# 1753            J     133                         NaN
# 1754            W     131                         NaN
# 1755            R      68                         NaN
# 1756            V      40                         NaN
# 1757          DOT      16              DOTCOM POSTAGE
# 1773         CRUK      16             CRUK Commission
# 1789  BANKCHARGES      12                         NaN
# 1790            T       5                         NaN
# 1791         PADS       4  PADS TO MATCH ALL CUSHIONS
# 1795            Y       3                         NaN
# 1796            I       3                         NaN
# 1797            O       1                         NaN
# 1798            Z       1                         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406829 entries, 0 to 406828
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 24.8+ MB

# %%
# Description : counting Manual, Discount,POSTAGE...
count_manual = (df['Description']=='Manual').sum()
count_discount = (df['Description']=='Discount').sum()
count_post = (df['Description']=='POSTAGE').sum()
count_cruk = (df['Description']=='CRUK Commission').sum()
count_dot = (df['Description']=='DOTCOM POSTAGE').sum()

print('Sum of value manual: ',count_manual)
print('Sum of value discount: ',count_discount)
print('Sum of value postage: ',count_post)
print('Sum of value cruk commission: ',count_cruk)
print('Sum of value dotcom postage: ',count_dot)
# Out:
# Sum of value manual:  465
# Sum of value discount:  77
# Sum of value postage:  1196
# Sum of value cruk commission:  16
# Sum of value dotcom postage:  16

# %%
#StockCode feature: finding the count of values that have a len less than 5 (which is a standard stockcode length)
#length of the values in the 'StockCode' column with less than 5 character does not match the 'StockCode' convention.
df_less_5 = df[df['StockCode'].str.len() < 5]
df_less_5.value_counts('StockCode')
# Out:
# StockCode
# POST    1196
# M        465
# C2       134
# D         77
# CRUK      16
# DOT       16
# PADS       4
# dtype: int64

# %% [markdown]
# # **Removing unwanted values from the StockCode column:**

# %%
# List of unwanted stock codes

# Filter rows where the 'StockCode' column values are not in the unwanted_stockcodes list
unusual_data = df['StockCode'].isin(['POST', 'M', 'C2', 'D', 'CRUK', 'DOT', 'PADS'])

df = df[~unusual_data]
print(df.shape)
# Out:
# (404921, 8)

# %%
df['StockCode'].isin(['POST', 'M', 'C2', 'D', 'CRUK', 'DOT', 'PADS']).sum()
# Out:
# 0

# %% [markdown]
# # **Checking the unit price feature:**

# %%
#checking the unit price feature
df[df['UnitPrice'] > 1000]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# # **checking the values in Quantity column:**

# %%
#checking the large negative value in Quantity
df[df['Quantity'] < -5000]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 3102     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 38125    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 406350   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 3102   2010-12-02 14:23:00       0.03     15838.0  United Kingdom
# 38125  2011-01-18 10:17:00       1.04     12346.0  United Kingdom
# 406350 2011-12-09 09:27:00       2.08     16446.0  United Kingdom

# %%
#checking the large negative value in Quantity
df[df['Quantity'] > 5000]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 38120     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 378894    578841     84826  ASSTD DESIGN 3D PAPER STICKERS     12540
# 406349    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 38120  2011-01-18 10:01:00       1.04     12346.0  United Kingdom
# 378894 2011-11-25 15:57:00       0.00     13256.0  United Kingdom
# 406349 2011-12-09 09:15:00       2.08     16446.0  United Kingdom

# %% [markdown]
# Checking the large negative and large positive values in Quantity column, the matching values in the "Description", "StockCode" COLUMNS reveal that these are returned items. So, they will be cancelled out ance no need to remove those outliers.

# %% [markdown]
# # **Feature Engineering:**

# %% [markdown]
# # **Recency, Frequency and Monetary values (RFM):**

# %% [markdown]
# # **Converting the date feature to a datetime object:**

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # **Recency:  the number of days since the customer's last purchase**

# %%
#setting the reference date to the latest date of the analysis
reference_date = df['InvoiceDate'].max()

#grouping data by customer and getting the latest purchase date for each customer
grouped_df = df.groupby('CustomerID')['InvoiceDate'].max().reset_index()

#calculatingthe recency for each customer by subtracting the most recent purchase date from the reference date
grouped_df['Recency'] = (reference_date - grouped_df['InvoiceDate']).dt.days

#merging the recency value to the dataframe
df = df.merge(grouped_df[['CustomerID', 'Recency']], on='CustomerID', how='left')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 404916    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 404917    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 404918    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 404919    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 404920    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Recency
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# ...                    ...        ...         ...             ...      ...
# 404916 2011-12-09 12:50:00       0.85     12680.0          France        0
# 404917 2011-12-09 12:50:00       2.10     12680.0          France        0
# 404918 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404919 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404920 2011-12-09 12:50:00       4.95     12680.0          France        0
#
# [404921 rows x 9 columns]

# %%
reference_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %% [markdown]
# # **Frequency:**

# %%
#calculating the frequency for each customer by counting the number of purchases
frequency_df = df.groupby('CustomerID')['InvoiceNo'].count()

#merging the frequency value to the dataframe
df = pd.merge(df,frequency_df, on='CustomerID', how='left')
df.rename(columns={'InvoiceNo_x':'InvoiceNo', 'InvoiceNo_y':'Frequency'}, inplace=True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 404916    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 404917    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 404918    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 404919    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 404920    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# ...                    ...        ...         ...             ...      ...
# 404916 2011-12-09 12:50:00       0.85     12680.0          France        0
# 404917 2011-12-09 12:50:00       2.10     12680.0          France        0
# 404918 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404919 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404920 2011-12-09 12:50:00       4.95     12680.0          France        0
#
#         Frequency
# 0             312
# 1             312
# 2             312
# 3             312
# 4             312
# ...           ...
# 404916         49
# 404917         49
# 404918         49
# 404919         49
# 404920         49
#
# [404921 rows x 10 columns]

# %%
frequency_df
# Out:
# CustomerID
# 12346.0      2
# 12347.0    182
# 12348.0     27
# 12349.0     72
# 12350.0     16
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     13
# 18283.0    754
# 18287.0     70
# Name: InvoiceNo, Length: 4363, dtype: int64

# %% [markdown]
# # **Monetary Value:**

# %%
#calculating the monetary value for each customer
monetary_value_df = df.groupby('CustomerID')['UnitPrice'].sum()

#merging the monetary value to the dataframe
df = df.merge(monetary_value_df, on='CustomerID', how='left')
df.rename(columns={'UnitPrice_x':'UnitPrice', 'UnitPrice_y':'MonetaryValue'}, inplace=True)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 404916    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 404917    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 404918    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 404919    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 404920    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# ...                    ...        ...         ...             ...      ...
# 404916 2011-12-09 12:50:00       0.85     12680.0          France        0
# 404917 2011-12-09 12:50:00       2.10     12680.0          France        0
# 404918 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404919 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404920 2011-12-09 12:50:00       4.95     12680.0          France        0
#
#         Frequency  MonetaryValue
# 0             312        1224.51
# 1             312        1224.51
# 2             312        1224.51
# 3             312        1224.51
# 4             312        1224.51
# ...           ...            ...
# 404916         49         135.17
# 404917         49         135.17
# 404918         49         135.17
# 404919         49         135.17
# 404920         49         135.17
#
# [404921 rows x 11 columns]

# %% [markdown]
# # **Segmentation of Customers using the RFM (Recency, Frequency, Monetary) score:**
#
# Customers with higher RFM scores are typically more valuable or active.

# %%
#normalizing the values
r_quartile = pd.qcut(df['Recency'], 4, labels=[4, 3, 2, 1])
f_quartile = pd.qcut(df['Frequency'], 4, labels=[1, 2, 3, 4])
m_quartile = pd.qcut(df['MonetaryValue'], 4, labels=[1, 2, 3, 4])
df['RFM_Score'] = r_quartile.astype(int) + f_quartile.astype(int) + m_quartile.astype(int)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 404916    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 404917    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 404918    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 404919    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 404920    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# ...                    ...        ...         ...             ...      ...
# 404916 2011-12-09 12:50:00       0.85     12680.0          France        0
# 404917 2011-12-09 12:50:00       2.10     12680.0          France        0
# 404918 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404919 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404920 2011-12-09 12:50:00       4.95     12680.0          France        0
#
#         Frequency  MonetaryValue  RFM_Score
# 0             312        1224.51          7
# 1             312        1224.51          7
# 2             312        1224.51          7
# 3             312        1224.51          7
# 4             312        1224.51          7
# ...           ...            ...        ...
# 404916         49         135.17          6
# 404917         49         135.17          6
# 404918         49         135.17          6
# 404919         49         135.17          6
# 404920         49         135.17          6
#
# [404921 rows x 12 columns]

# %% [markdown]
# # **Calculate the RFM_Level to Seggregate  customers:**

# %%
def assign_rfm_level(row):
    """
    Assigns the RFM level based on the RFM score.

    Parameters:
    row (pandas.Series): A row from the DataFrame containing RFM scores.

    Returns:
    str: The RFM level category as string.
    """

    if row['RFM_Score'] >= 10:
        return 'Best Customers'
    elif 6 <= row['RFM_Score'] < 10:  # Simplified condition using chaining comparison
        return 'Loyal Customers'
    elif 4 <= row['RFM_Score'] < 6:   # Simplified condition using chaining comparison
        return 'Potential Loyalists'
    elif 2 <= row['RFM_Score'] < 4:   # Simplified condition using chaining comparison
        return 'Promising'
    else:
        return 'Needs Attention'

# Apply the function to each row of the DataFrame retail along the axis 1 (row-wise)
df['RFM_Level'] = df.apply(assign_rfm_level, axis=1)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 404916    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 404917    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 404918    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 404919    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 404920    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# ...                    ...        ...         ...             ...      ...
# 404916 2011-12-09 12:50:00       0.85     12680.0          France        0
# 404917 2011-12-09 12:50:00       2.10     12680.0          France        0
# 404918 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404919 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404920 2011-12-09 12:50:00       4.95     12680.0          France        0
#
#         Frequency  MonetaryValue  RFM_Score        RFM_Level
# 0             312        1224.51          7  Loyal Customers
# 1             312        1224.51          7  Loyal Customers
# 2             312        1224.51          7  Loyal Customers
# 3             312        1224.51          7  Loyal Customers
# 4             312        1224.51          7  Loyal Customers
# ...           ...            ...        ...              ...
# 404916         49         135.17          6  Loyal Customers
# 404917         49         135.17          6  Loyal Customers
# 404918         49         135.17          6  Loyal Customers
# 404919         49         135.17          6  Loyal Customers
# 404920         49         135.17          6  Loyal Customers
#
# [404921 rows x 13 columns]

# %% [markdown]
# # **Visualizing the RFM Level using a bar plot:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the figure size
plt.figure(figsize=(7, 5))

# Create a countplot to visualize the number of customers per RFM level
sns.countplot(data=df, hue='RFM_Level',x='RFM_Level', palette='Set3')

# Set labels and title
plt.xlabel('RFM Level', fontsize=12)
plt.ylabel('Number of Customers')
plt.title('RFM Levels of Customers')

# Show the plot
plt.show()

# %% [markdown]
# # **Calculates the mean values for 'Recency', 'Frequency', and 'MonetaryValue' within each group:**

# %%
segmented_customers = df.groupby('RFM_Level').agg({
    'Recency': 'mean',
    'Frequency': 'mean',
    'MonetaryValue': ['mean', 'count']
})
segmented_customers.T
# Out:
# RFM_Level            Best Customers  Loyal Customers  Potential Loyalists  \
# Recency       mean         4.432232        23.216174            58.865942
# Frequency     mean      1815.432773       223.244631            87.589062
# MonetaryValue mean      5244.151497       614.814420           245.280141
#               count   125627.000000    156832.000000         71894.000000
#
# RFM_Level               Promising
# Recency       mean     146.128263
# Frequency     mean      41.723620
# MonetaryValue mean     115.478936
#               count  50568.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'segmented_customers' contains the segmented customer data

# Create a heatmap using sns.heatmap with the 'viridis' colormap
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(segmented_customers, cmap='viridis', annot=True, fmt='.2f', linewidths=.5)

# Rotate x-axis labels by 45 degrees
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45)

plt.title('Characteristics of Segmented Customers')
plt.xlabel('Metrics')
plt.ylabel('RFM Level')
plt.show()

# %% [markdown]
# INTERPRETATION:
#
#  "Loyal Customers" have higher mean values for "MonetaryValue" compared to other segments, it suggests that targeting strategies should focus more on retaining these high-value customers.
#
#  In the context of RFM (Recency, Frequency, MonetaryValue) analysis, lower recency is generally considered better. So, it is better to follow up to the "Promising", "Potential Loyalists", and 'Loyal Customers' with freqent emails and mails about the promotion/deal of products.

# %% [markdown]
# # **Comparing the trends or differences in mean values of RFM metrics across different RFM levels**

# %%
import matplotlib.pyplot as plt
# Extract mean and count values for Recency, Frequency, and MonetaryValue
recency_mean = segmented_customers.loc[:, ('Recency', 'mean')]
frequency_mean = segmented_customers.loc[:, ('Frequency', 'mean')]
monetary_value_mean = segmented_customers.loc[:, ('MonetaryValue', 'mean')]
monetary_value_count = segmented_customers.loc[:, ('MonetaryValue', 'count')]

# Create line plots
plt.figure(figsize=(10, 6))

# Plot mean values
plt.plot(recency_mean, c='blue', label='Recency (mean)')
plt.plot(frequency_mean, c='red', label='Frequency (mean)')
plt.plot(monetary_value_mean, c='green', label='Monetary Value (mean)')

# Plot count values (using a different linestyle)
plt.plot(monetary_value_count, c='orange', linestyle='--', label='Monetary Value (count)')

# Add labels and title
plt.xlabel('Customer Segment (RFM Level)')
plt.ylabel('Value')
plt.title('Line Plot of Mean Recency, Frequency, and Monetary Value')
plt.legend()
plt.grid(True)  # Add grid for better readability
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees for better readability
plt.show()

# %% [markdown]
# **INTERPRETATION:**
#
# Higher mean Recency indicates that customers in that segment made purchases less recently.
#
# Higher mean Frequency indicates that customers in "Best Customers" segment make purchases more frequently.
#
# Higher mean Monetary Value indicates that customers the "Loyal Customer" segment spend more on average.
#
# Insights for Business Strategy:
#
# Based on the plot, the following business strategiesshould be adopted:
#
# Targeting marketing efforts towards segments with high mean Frequency (best Customer) and Monetary Value (Loyal Customer) to retain and upsell to valuable customers.
#
# Implementing re-engagement strategies for "Potential Loyalties" and "Promising" customers with low mean Recency to reactivate inactive customers.

# %% [markdown]
# # **Product Segmentation using the Kmeans Clustering:**

# %% [markdown]
# # **Clustering products into product categories**

# %%
# !pip install nltk
import nltk
nltk.download('stopwords')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import Counter

# Tokenize the product descriptions
df['Tokenized_Description'] = df['Description'].apply(word_tokenize)

# Remove stop words
stop_words = set(stopwords.words('english'))
df['Tokenized_Description'] = df['Tokenized_Description'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# Perform stemming
stemmer = PorterStemmer()
df['Tokenized_Description'] = df['Tokenized_Description'].apply(lambda x: [stemmer.stem(word) for word in x])

# Perform word frequency analysis
df['Word_Counts'] = df['Tokenized_Description'].apply(Counter)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 404916    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 404917    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 404918    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 404919    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 404920    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# ...                    ...        ...         ...             ...      ...
# 404916 2011-12-09 12:50:00       0.85     12680.0          France        0
# 404917 2011-12-09 12:50:00       2.10     12680.0          France        0
# 404918 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404919 2011-12-09 12:50:00       4.15     12680.0          France        0
# 404920 2011-12-09 12:50:00       4.95     12680.0          France        0
#
#         Frequency  MonetaryValue  RFM_Score        RFM_Level  \
# 0             312        1224.51          7  Loyal Customers
# 1             312        1224.51          7  Loyal Customers
# 2             312        1224.51          7  Loyal Customers
# 3             312        1224.51          7  Loyal Customers
# 4             312        1224.51          7  Loyal Customers
# ...           ...            ...        ...              ...
# 404916         49         135.17          6  Loyal Customers
# 404917         49         135.17          6  Loyal Customers
# 404918         49         135.17          6  Loyal Customers
# 404919         49         135.17          6  Loyal Customers
# 404920         49         135.17          6  Loyal Customers
#
#                          Tokenized_Description  \
# 0        [white, hang, heart, t-light, holder]
# 1                      [white, metal, lantern]
# 2          [cream, cupid, heart, coat, hanger]
# 3       [knit, union, flag, hot, water, bottl]
# 4        [red, woolli, hotti, white, heart, .]
# ...                                        ...
# 404916            [pack, 20, spaceboy, napkin]
# 404917      [children, 's, apron, dolli, girl]
# 404918        [children, cutleri, dolli, girl]
# 404919       [children, cutleri, circu, parad]
# 404920         [bake, set, 9, piec, retrospot]
#
#                                               Word_Counts
# 0       {'white': 1, 'hang': 1, 'heart': 1, 't-light':...
# 1                  {'white': 1, 'metal': 1, 'lantern': 1}
# 2       {'cream': 1, 'cupid': 1, 'heart': 1, 'coat': 1...
# 3       {'knit': 1, 'union': 1, 'flag': 1, 'hot': 1, '...
# 4       {'red': 1, 'woolli': 1, 'hotti': 1, 'white': 1...
# ...                                                   ...
# 404916   {'pack': 1, '20': 1, 'spaceboy': 1, 'napkin': 1}
# 404917  {'children': 1, ''s': 1, 'apron': 1, 'dolli': ...
# 404918  {'children': 1, 'cutleri': 1, 'dolli': 1, 'gir...
# 404919  {'children': 1, 'cutleri': 1, 'circu': 1, 'par...
# 404920  {'bake': 1, 'set': 1, '9': 1, 'piec': 1, 'retr...
#
# [404921 rows x 15 columns]

# %% [markdown]
# # **Converting the text columns into numeric one using the TfidfVectorizer:**
#
# This code works for all the text-related column.

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
#
#    Frequency  MonetaryValue  RFM_Score        RFM_Level  \
# 0        312        1224.51          7  Loyal Customers
# 1        312        1224.51          7  Loyal Customers
# 2        312        1224.51          7  Loyal Customers
# 3        312        1224.51          7  Loyal Customers
# 4        312        1224.51          7  Loyal Customers
#
#                     Tokenized_Description  \
# 0   [white, hang, heart, t-light, holder]
# 1                 [white, metal, lantern]
# 2     [cream, cupid, heart, coat, hanger]
# 3  [knit, union, flag, hot, water, bottl]
# 4   [red, woolli, hotti, white, heart, .]
#
#                                          Word_Counts
# 0  {'white': 1, 'hang': 1, 'heart': 1, 't-light':...
# 1             {'white': 1, 'metal': 1, 'lantern': 1}
# 2  {'cream': 1, 'cupid': 1, 'heart': 1, 'coat': 1...
# 3  {'knit': 1, 'union': 1, 'flag': 1, 'hot': 1, '...
# 4  {'red': 1, 'woolli': 1, 'hotti': 1, 'white': 1...

# %% [markdown]
# # **Text Vectorization**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Create an instance of TfidfVectorizer
tfidf = TfidfVectorizer()

# Convert the tokenized descriptions into a TF-IDF matrix
tfidf_matrix = tfidf.fit_transform([' '.join(x) for x in df['Tokenized_Description']])

# %% [markdown]
# # **Selecting the optimal number of clusters using the "Elbow Method" for Product Segmentation:**
#
# The Elbow Method is a technique used in unsupervised machine learning, particularly in clustering algorithms like k-means, to determine the optimal number of clusters for a given dataset.
#
# The Elbow Method provides a heuristic approach to selecting the optimal number of clusters for a dataset based on the behavior of the within-cluster sum of squares (WCSS) as the number of clusters varies. It's a useful tool for determining an appropriate number of clusters when using clustering algorithms like k-means.
#
# A heuristic approach is a problem-solving strategy or method that uses practical, intuitive, and common-sense principles to guide decision-making or find solutions, especially when dealing with complex or ill-defined problems. Heuristic methods are often used when an optimal solution is difficult or impossible to obtain due to various constraints such as time, computational resources, or incomplete information.
#
# The idea behind the elbow method is to choose k at the elbow point, where the decrease in WCSS is the greatest.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# List to store the within-cluster sum of squares (WCSS) for different numbers of clusters
wcss = []

# Iterate over a range of values for the number of clusters (k)
for k in range(1, 11):
    # Initialize and fit KMeans clustering algorithm for the current value of k
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(tfidf_matrix)

    # Append the WCSS (inertia) to the list
    wcss.append(kmeans.inertia_)

# Plot the Elbow Method visualization
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
plt.show()

# %% [markdown]
# # **Display the Elbow Method visualization**

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
import numpy as np

# Convert the TF-IDF matrix to a dense numpy array
tfidf_array = tfidf_matrix.toarray()

# Create an instance of KMeans clustering algorithm
kmeans = KMeans()

# Create an instance of KElbowVisualizer with KMeans clustering algorithm and specify the range of k values
elbow_method = KElbowVisualizer(kmeans, k=10)

# Fit the visualizer on the TF-IDF matrix (converted to a numpy array)
elbow_method.fit(tfidf_array)

# Display the Elbow Method visualization
elbow_method.show()

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from scipy.sparse import csr_matrix

# %%
# Convert the TF-IDF matrix to a dense numpy array
tfidf_array = tfidf_matrix.toarray()

# Create an instance of MiniBatchKMeans clustering algorithm
kmeans = MiniBatchKMeans()

# Create an instance of KElbowVisualizer with MiniBatchKMeans clustering algorithm and specify the range of k values
elbow_method = KElbowVisualizer(kmeans, k=10)

# Fit the visualizer on the TF-IDF matrix (converted to a dense numpy array)
elbow_method.fit(tfidf_array)

# Display the Elbow Method visualization
elbow_method.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for MiniBatchKMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# # **Using the KMeans algorithm to cluster the PRODUCT data into three clusters:**

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(tfidf_matrix)
df['Product_Cluster'] = kmeans.predict(tfidf_matrix)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
#
#    Frequency  MonetaryValue  RFM_Score        RFM_Level  \
# 0        312        1224.51          7  Loyal Customers
# 1        312        1224.51          7  Loyal Customers
# 2        312        1224.51          7  Loyal Customers
# 3        312        1224.51          7  Loyal Customers
# 4        312        1224.51          7  Loyal Customers
#
#                     Tokenized_Description  \
# 0   [white, hang, heart, t-light, holder]
# 1                 [white, metal, lantern]
# 2     [cream, cupid, heart, coat, hanger]
# 3  [knit, union, flag, hot, water, bottl]
# 4   [red, woolli, hotti, white, heart, .]
#
#                                          Word_Counts  Product_Cluster
# 0  {'white': 1, 'hang': 1, 'heart': 1, 't-light':...                0
# 1             {'white': 1, 'metal': 1, 'lantern': 1}                1
# 2  {'cream': 1, 'cupid': 1, 'heart': 1, 'coat': 1...                0
# 3  {'knit': 1, 'union': 1, 'flag': 1, 'hot': 1, '...                1
# 4  {'red': 1, 'woolli': 1, 'hotti': 1, 'white': 1...                0

# %% [markdown]
# # **Visualizing the Product Category Clusters:**

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

# Reduce the dimensionality of the TF-IDF matrix using TruncatedSVD
svd = TruncatedSVD(n_components=2)
tfidf_svd = svd.fit_transform(tfidf_matrix)

# Plot the clusters
plt.figure(figsize=(8, 6))
for cluster in range(3):  # Assuming you have 3 clusters
    plt.scatter(tfidf_svd[df['Product_Cluster'] == cluster, 0],
                tfidf_svd[df['Product_Cluster'] == cluster, 1],
                label=f'Cluster {cluster}')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Product Category Clusters (K-Means)')
plt.legend()
plt.show()

# %% [markdown]
# **Interpretation:**
#
# -Cluster Distribution:
#
# The scatter plot shows the distribution of data points (products) in the reduced two-dimensional space.
#
# Each point represents a product, and its position on the plot is determined by its two principal components obtained from TruncatedSVD.
#
# -Cluster Separation:
#
# The distinct colors represent different product category clusters.
#
# Points that are closer together in the plot are more similar in terms of their TF-IDF representations.
#
# -Cluster Interpretation:
#
# Products within the same cluster are expected to share similar characteristics or descriptions, as they are grouped together by the K-means algorithm.
#
# -Cluster Insights:
#
# Clusters that are well-separated in the plot indicate clear distinctions between product categories based on their descriptions.
#
# Overlapping clusters suggest similarities or ambiguities in the descriptions of products within those clusters.

# %% [markdown]
# # **Customer Segmentation using the Kmeans Clustering:**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404921 entries, 0 to 404920
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   InvoiceNo              404921 non-null  object
#  1   StockCode              404921 non-null  object
#  2   Description            404921 non-null  object
#  3   Quantity               404921 non-null  int64
#  4   InvoiceDate            404921 non-null  datetime64[ns]
#  5   UnitPrice              404921 non-null  float64
#  6   CustomerID             404921 non-null  float64
#  7   Country                404921 non-null  object
#  8   Recency                404921 non-null  int64
#  9   Frequency              404921 non-null  int64
#  10  MonetaryValue          404921 non-null  float64
#  11  RFM_Score              404921 non-null  int64
#  12  RFM_Level              404921 non-null  object
#  13  Tokenized_Description  404921 non-null  object
#  14  Word_Counts            404921 non-null  object
#  15  Product_Cluster        404921 non-null  int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(7)
# memory usage: 51.0+ MB

# %% [markdown]
# # **Selecting only numeric features:**
#
# K-means clustering assumes that the data points are represented as numeric vectors in a continuous feature space.
#
# Since Categorical or textual data may not adhere to this assumptions and may require additional preprocessing or transformation before being used with
# K-means clustering, we only consider the numeric variables for the K-means clustering.

# %%
features = ['Quantity', 'UnitPrice', 'Recency', 'Frequency', 'MonetaryValue', 'RFM_Score', 'Product_Cluster']
X = df[features]

# %%
X.shape
# Out:
# (404921, 7)

# %%
#scaling data using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# applying PCA : n_components=3

# The primary objective of PCA is to find a lower-dimensional representation of the data that captures as much variance as possible.
from sklearn.decomposition import PCA
pca = PCA(3, svd_solver = 'full')
pca.fit(X_scaled)
dimreduce_X = pca.transform(X_scaled)
dimreduce_X
# Out:
# array([[-1.75226484,  3.32126005, -0.98133272],
#        [-1.69828003,  2.49542399, -0.42984188],
#        [-1.75253285,  3.33534265, -0.96668678],
#        ...,
#        [-0.52283321, -0.41165767,  0.26745451],
#        [-0.52283321, -0.41165767,  0.26745451],
#        [-0.52380504, -0.35183891,  0.3562683 ]])

# %%
#Converting an array dimreduce_X into a dataframe with PCA output
columns = ['principal_comp_%i' % i for i in range(1,4)]
X_pca  = pd.DataFrame(dimreduce_X, columns = columns)
X_pca.head()
# Out:
#    principal_comp_1  principal_comp_2  principal_comp_3
# 0         -1.752265          3.321260         -0.981333
# 1         -1.698280          2.495424         -0.429842
# 2         -1.752533          3.335343         -0.966687
# 3         -1.698280          2.495424         -0.429842
# 4         -1.753297          3.383663         -0.891605

# %%
# #visualizing df_principal in 3D
fig = plt.figure(figsize = (14, 12))
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X_pca['principal_comp_1'], X_pca['principal_comp_2'], X_pca['principal_comp_3'],
           s = 20, c = '#eae2b7', edgecolors = '#d62828')
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('Principal Component Dimensions')
plt.show();

# %% [markdown]
# # **Selecting the optimal number of clusters using the "Elbow Method" for Customer Segmentation:**
#
# Determing k for customer dataset

# %%
from sklearn.cluster import MiniBatchKMeans
from yellowbrick.cluster import KElbowVisualizer

# Create an instance of MiniBatchKMeans clustering algorithm
kmeans_mini = MiniBatchKMeans()

# Create an instance of KElbowVisualizer with MiniBatchKMeans clustering algorithm and specify the range of k values
elbow_method_mini = KElbowVisualizer(kmeans_mini, k=10)

# Fit the visualizer on the PCA-transformed data
elbow_method_mini.fit(X_pca)

# Display the Elbow Method visualization
elbow_method_mini.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for MiniBatchKMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# # **Using the KMeans algorithm to cluster the customer data into four clusters:**

# %%
#performing k-means clustering
kmeans = KMeans(n_clusters = 3)
kmeans_pred = kmeans.fit_predict(X_pca)
kmeans_pred
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 2, 2, 2], dtype=int32)

# %%
# add predicted clusters for each data point into dataframe
df['Customer_Cluster']= kmeans_pred

# add predicted clusters for each data point into reduced dimension data
X_pca['Customer_Cluster'] = kmeans_pred

# %%
X_pca.head()
# Out:
#    principal_comp_1  principal_comp_2  principal_comp_3  Customer_Cluster
# 0         -1.752265          3.321260         -0.981333                 1
# 1         -1.698280          2.495424         -0.429842                 1
# 2         -1.752533          3.335343         -0.966687                 1
# 3         -1.698280          2.495424         -0.429842                 1
# 4         -1.753297          3.383663         -0.891605                 1

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Recency  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom      301
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom      301
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom      301
#
#    Frequency  MonetaryValue  RFM_Score        RFM_Level  \
# 0        312        1224.51          7  Loyal Customers
# 1        312        1224.51          7  Loyal Customers
# 2        312        1224.51          7  Loyal Customers
# 3        312        1224.51          7  Loyal Customers
# 4        312        1224.51          7  Loyal Customers
#
#                     Tokenized_Description  \
# 0   [white, hang, heart, t-light, holder]
# 1                 [white, metal, lantern]
# 2     [cream, cupid, heart, coat, hanger]
# 3  [knit, union, flag, hot, water, bottl]
# 4   [red, woolli, hotti, white, heart, .]
#
#                                          Word_Counts  Product_Cluster  \
# 0  {'white': 1, 'hang': 1, 'heart': 1, 't-light':...                0
# 1             {'white': 1, 'metal': 1, 'lantern': 1}                1
# 2  {'cream': 1, 'cupid': 1, 'heart': 1, 'coat': 1...                0
# 3  {'knit': 1, 'union': 1, 'flag': 1, 'hot': 1, '...                1
# 4  {'red': 1, 'woolli': 1, 'hotti': 1, 'white': 1...                0
#
#    Customer_Cluster
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
# checking out the count per cluster
sns.countplot(X_pca, x = 'Customer_Cluster', palette = "Set1")
# Out:
# <ipython-input-104-cfbc4a63d3ee>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(X_pca, x = 'Customer_Cluster', palette = "Set1")
# <Axes: xlabel='Customer_Cluster', ylabel='count'>

# %%
#visualizing clusterd reduced dimension data in 3D
fig = plt.figure(figsize = (12,9))
ax = fig.add_subplot(111, projection='3d')
x = np.array(X_pca['principal_comp_1'])
y = np.array(X_pca['principal_comp_2'])
z = np.array(X_pca['principal_comp_3'])

ax.scatter(x,y,z, marker = 's', c = X_pca['Customer_Cluster'], s = 40, cmap="RdBu")

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('Visualization of Customer Cluster')
plt.show()

# %% [markdown]
# # **Plotting the pairwise scatterplot matrix for the columns 'MonetaryValue', 'Frequency', and 'Recency' from the original DataFrame, with each scatterplot colored by the 'Customer Cluster' column:**

# %%
sns.set(style='ticks')
sns.pairplot(df[['MonetaryValue', 'Frequency', 'Recency', 'Customer_Cluster']], hue = 'Customer_Cluster')

# %% [markdown]
# This pairplot visualizes the relationships between the numeric features ('MonetaryValue', 'Frequency', and 'Recency') and observe how the data points are distributed across different clusters.
